# %%
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is 
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import pandas as pd
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("diabetes.csv")

# %%
# X = df.data[:, 2:] 
# y = df.target

# %%
df.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
features = ['Preg','age','Plas','skin','test','mass','Pres','pedi']
X = df[features] 
y = df['class']

# %%
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)

tree.plot_tree(dtree, feature_names=features)
# Out:
# [Text(0.48618521341463417, 0.9642857142857143, 'Plas <= 127.5\ngini = 0.454\nsamples = 768\nvalue = [500, 268]'),
#  Text(0.20509400406504066, 0.8928571428571429, 'age <= 28.5\ngini = 0.313\nsamples = 485\nvalue = [391, 94]'),
#  Text(0.10518292682926829, 0.8214285714285714, 'mass <= 45.4\ngini = 0.155\nsamples = 271\nvalue = [248, 23]'),
#  Text(0.0701219512195122, 0.75, 'mass <= 30.95\ngini = 0.139\nsamples = 267\nvalue = [247, 20]'),
#  Text(0.024390243902439025, 0.6785714285714286, 'Preg <= 7.5\ngini = 0.026\nsamples = 151\nvalue = [149, 2]'),
#  Text(0.016260162601626018, 0.6071428571428571, 'pedi <= 0.672\ngini = 0.013\nsamples = 150\nvalue = [149, 1]'),
#  Text(0.008130081300813009, 0.5357142857142857, 'gini = 0.0\nsamples = 131\nvalue = [131, 0]'),
#  Text(0.024390243902439025, 0.5357142857142857, 'pedi <= 0.686\ngini = 0.1\nsamples = 19\nvalue = [18, 1]'),
#  Text(0.016260162601626018, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.032520325203252036, 0.4642857142857143, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(0.032520325203252036, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.11585365853658537, 0.6785714285714286, 'pedi <= 0.501\ngini = 0.262\nsamples = 116\nvalue = [98, 18]'),
#  Text(0.07317073170731707, 0.6071428571428571, 'Pres <= 53.0\ngini = 0.153\nsamples = 72\nvalue = [66, 6]'),
#  Text(0.056910569105691054, 0.5357142857142857, 'Preg <= 2.5\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.04878048780487805, 0.4642857142857143, 'skin <= 10.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(0.04065040650406504, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.056910569105691054, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.06504065040650407, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08943089430894309, 0.5357142857142857, 'test <= 36.5\ngini = 0.087\nsamples = 66\nvalue = [63, 3]'),
#  Text(0.08130081300813008, 0.4642857142857143, 'test <= 34.0\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.07317073170731707, 0.39285714285714285, 'Plas <= 111.5\ngini = 0.165\nsamples = 22\nvalue = [20, 2]'),
#  Text(0.06504065040650407, 0.32142857142857145, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.08130081300813008, 0.32142857142857145, 'Plas <= 116.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.07317073170731707, 0.25, 'age <= 22.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.06504065040650407, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.08130081300813008, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.08943089430894309, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.08943089430894309, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.0975609756097561, 0.4642857142857143, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(0.15853658536585366, 0.6071428571428571, 'Pres <= 69.0\ngini = 0.397\nsamples = 44\nvalue = [32, 12]'),
#  Text(0.12195121951219512, 0.5357142857142857, 'Plas <= 88.5\ngini = 0.476\nsamples = 23\nvalue = [14, 9]'),
#  Text(0.11382113821138211, 0.4642857142857143, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(0.13008130081300814, 0.4642857142857143, 'Plas <= 116.0\ngini = 0.48\nsamples = 15\nvalue = [6, 9]'),
#  Text(0.11382113821138211, 0.39285714285714285, 'mass <= 32.25\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.10569105691056911, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.12195121951219512, 0.32142857142857145, 'test <= 99.5\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.11382113821138211, 0.25, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(0.13008130081300814, 0.25, 'Preg <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.12195121951219512, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.13821138211382114, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.14634146341463414, 0.39285714285714285, 'mass <= 34.1\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.13821138211382114, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.15447154471544716, 0.32142857142857145, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.1951219512195122, 0.5357142857142857, 'pedi <= 1.098\ngini = 0.245\nsamples = 21\nvalue = [18, 3]'),
#  Text(0.18699186991869918, 0.4642857142857143, 'skin <= 5.5\ngini = 0.18\nsamples = 20\nvalue = [18, 2]'),
#  Text(0.17886178861788618, 0.39285714285714285, 'Pres <= 79.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.17073170731707318, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.18699186991869918, 0.32142857142857145, 'Preg <= 1.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.17886178861788618, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1951219512195122, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.1951219512195122, 0.39285714285714285, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.2032520325203252, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.1402439024390244, 0.75, 'age <= 22.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.13211382113821138, 0.6785714285714286, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.1483739837398374, 0.6785714285714286, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.305005081300813, 0.8214285714285714, 'mass <= 26.35\ngini = 0.443\nsamples = 214\nvalue = [143, 71]'),
#  Text(0.24390243902439024, 0.75, 'mass <= 9.65\ngini = 0.093\nsamples = 41\nvalue = [39, 2]'),
#  Text(0.23577235772357724, 0.6785714285714286, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.25203252032520324, 0.6785714285714286, 'gini = 0.0\nsamples = 39\nvalue = [39, 0]'),
#  Text(0.36610772357723576, 0.75, 'Plas <= 99.5\ngini = 0.48\nsamples = 173\nvalue = [104, 69]'),
#  Text(0.2682926829268293, 0.6785714285714286, 'Plas <= 28.5\ngini = 0.298\nsamples = 55\nvalue = [45, 10]'),
#  Text(0.2601626016260163, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.2764227642276423, 0.6071428571428571, 'pedi <= 0.796\ngini = 0.256\nsamples = 53\nvalue = [45, 8]'),
#  Text(0.24390243902439024, 0.5357142857142857, 'Plas <= 94.5\ngini = 0.162\nsamples = 45\nvalue = [41, 4]'),
#  Text(0.21951219512195122, 0.4642857142857143, 'Preg <= 11.5\ngini = 0.059\nsamples = 33\nvalue = [32, 1]'),
#  Text(0.21138211382113822, 0.39285714285714285, 'gini = 0.0\nsamples = 30\nvalue = [30, 0]'),
#  Text(0.22764227642276422, 0.39285714285714285, 'mass <= 31.25\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.21951219512195122, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.23577235772357724, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.2682926829268293, 0.4642857142857143, 'Plas <= 97.5\ngini = 0.375\nsamples = 12\nvalue = [9, 3]'),
#  Text(0.2601626016260163, 0.39285714285714285, 'mass <= 36.2\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.25203252032520324, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.2682926829268293, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.2764227642276423, 0.39285714285714285, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.3089430894308943, 0.5357142857142857, 'skin <= 35.5\ngini = 0.5\nsamples = 8\nvalue = [4, 4]'),
#  Text(0.3008130081300813, 0.4642857142857143, 'Preg <= 6.0\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(0.2926829268292683, 0.39285714285714285, 'test <= 33.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.2845528455284553, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.3008130081300813, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3089430894308943, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3170731707317073, 0.4642857142857143, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4639227642276423, 0.6785714285714286, 'pedi <= 0.561\ngini = 0.5\nsamples = 118\nvalue = [59, 59]'),
#  Text(0.383130081300813, 0.6071428571428571, 'pedi <= 0.2\ngini = 0.482\nsamples = 84\nvalue = [50, 34]'),
#  Text(0.34146341463414637, 0.5357142857142857, 'mass <= 27.65\ngini = 0.308\nsamples = 21\nvalue = [17, 4]'),
#  Text(0.3333333333333333, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.34959349593495936, 0.4642857142857143, 'Preg <= 5.5\ngini = 0.255\nsamples = 20\nvalue = [17, 3]'),
#  Text(0.34146341463414637, 0.39285714285714285, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.35772357723577236, 0.39285714285714285, 'mass <= 34.55\ngini = 0.397\nsamples = 11\nvalue = [8, 3]'),
#  Text(0.34959349593495936, 0.32142857142857145, 'skin <= 16.0\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(0.34146341463414637, 0.25, 'mass <= 29.35\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.3333333333333333, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.34959349593495936, 0.17857142857142858, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.35772357723577236, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.36585365853658536, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.4247967479674797, 0.5357142857142857, 'Preg <= 1.5\ngini = 0.499\nsamples = 63\nvalue = [33, 30]'),
#  Text(0.3983739837398374, 0.4642857142857143, 'Plas <= 113.0\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(0.3902439024390244, 0.39285714285714285, 'mass <= 36.15\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.3821138211382114, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.3983739837398374, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4065040650406504, 0.39285714285714285, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.45121951219512196, 0.4642857142857143, 'Pres <= 67.0\ngini = 0.482\nsamples = 52\nvalue = [31, 21]'),
#  Text(0.42276422764227645, 0.39285714285714285, 'pedi <= 0.362\ngini = 0.375\nsamples = 12\nvalue = [3, 9]'),
#  Text(0.4146341463414634, 0.32142857142857145, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.43089430894308944, 0.32142857142857145, 'mass <= 30.05\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.42276422764227645, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.43902439024390244, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.4796747967479675, 0.39285714285714285, 'mass <= 34.45\ngini = 0.42\nsamples = 40\nvalue = [28, 12]'),
#  Text(0.4634146341463415, 0.32142857142857145, 'Pres <= 83.0\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.45528455284552843, 0.25, 'Plas <= 120.0\ngini = 0.499\nsamples = 19\nvalue = [9, 10]'),
#  Text(0.43902439024390244, 0.17857142857142858, 'pedi <= 0.252\ngini = 0.346\nsamples = 9\nvalue = [2, 7]'),
#  Text(0.43089430894308944, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.44715447154471544, 0.10714285714285714, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.4715447154471545, 0.17857142857142858, 'pedi <= 0.239\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.4634146341463415, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.4796747967479675, 0.10714285714285714, 'age <= 30.5\ngini = 0.219\nsamples = 8\nvalue = [7, 1]'),
#  Text(0.4715447154471545, 0.03571428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4878048780487805, 0.03571428571428571, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.4715447154471545, 0.25, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.4959349593495935, 0.32142857142857145, 'Plas <= 101.0\ngini = 0.208\nsamples = 17\nvalue = [15, 2]'),
#  Text(0.4878048780487805, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5040650406504065, 0.25, 'mass <= 43.1\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(0.4959349593495935, 0.17857142857142858, 'gini = 0.0\nsamples = 15\nvalue = [15, 0]'),
#  Text(0.5121951219512195, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.5447154471544715, 0.6071428571428571, 'Preg <= 6.5\ngini = 0.389\nsamples = 34\nvalue = [9, 25]'),
#  Text(0.5365853658536586, 0.5357142857142857, 'test <= 120.5\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(0.5121951219512195, 0.4642857142857143, 'age <= 34.5\ngini = 0.463\nsamples = 11\nvalue = [7, 4]'),
#  Text(0.5040650406504065, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.5203252032520326, 0.39285714285714285, 'mass <= 33.15\ngini = 0.444\nsamples = 6\nvalue = [2, 4]'),
#  Text(0.5121951219512195, 0.32142857142857145, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.5284552845528455, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.5609756097560976, 0.4642857142857143, 'skin <= 47.5\ngini = 0.32\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.5528455284552846, 0.39285714285714285, 'test <= 225.0\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(0.5447154471544715, 0.32142857142857145, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.5609756097560976, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5691056910569106, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5528455284552846, 0.5357142857142857, 'gini = 0.0\nsamples = 13\nvalue = [0, 13]'),
#  Text(0.7672764227642277, 0.8928571428571429, 'mass <= 29.95\ngini = 0.474\nsamples = 283\nvalue = [109, 174]'),
#  Text(0.6585365853658537, 0.8214285714285714, 'Plas <= 145.5\ngini = 0.432\nsamples = 76\nvalue = [52, 24]'),
#  Text(0.6341463414634146, 0.75, 'test <= 132.5\ngini = 0.25\nsamples = 41\nvalue = [35, 6]'),
#  Text(0.6260162601626016, 0.6785714285714286, 'mass <= 28.15\ngini = 0.337\nsamples = 28\nvalue = [22, 6]'),
#  Text(0.6097560975609756, 0.6071428571428571, 'Pres <= 73.0\ngini = 0.227\nsamples = 23\nvalue = [20, 3]'),
#  Text(0.6016260162601627, 0.5357142857142857, 'Pres <= 71.0\ngini = 0.444\nsamples = 9\nvalue = [6, 3]'),
#  Text(0.5934959349593496, 0.4642857142857143, 'Plas <= 129.5\ngini = 0.375\nsamples = 8\nvalue = [6, 2]'),
#  Text(0.5853658536585366, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6016260162601627, 0.39285714285714285, 'Pres <= 56.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.5934959349593496, 0.32142857142857145, 'age <= 42.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.5853658536585366, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6016260162601627, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6097560975609756, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6097560975609756, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6178861788617886, 0.5357142857142857, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(0.6422764227642277, 0.6071428571428571, 'skin <= 21.0\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.6341463414634146, 0.5357142857142857, 'Plas <= 135.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.6260162601626016, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6422764227642277, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.6504065040650406, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6422764227642277, 0.6785714285714286, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(0.6829268292682927, 0.75, 'age <= 25.5\ngini = 0.5\nsamples = 35\nvalue = [17, 18]'),
#  Text(0.6747967479674797, 0.6785714285714286, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6910569105691057, 0.6785714285714286, 'age <= 61.0\ngini = 0.487\nsamples = 31\nvalue = [13, 18]'),
#  Text(0.6829268292682927, 0.6071428571428571, 'mass <= 27.1\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(0.6666666666666666, 0.5357142857142857, 'Plas <= 151.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.6585365853658537, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6747967479674797, 0.4642857142857143, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(0.6991869918699187, 0.5357142857142857, 'Pres <= 82.0\ngini = 0.498\nsamples = 15\nvalue = [8, 7]'),
#  Text(0.6910569105691057, 0.4642857142857143, 'pedi <= 0.397\ngini = 0.463\nsamples = 11\nvalue = [4, 7]'),
#  Text(0.6829268292682927, 0.39285714285714285, 'Preg <= 6.5\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(0.6747967479674797, 0.32142857142857145, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.6910569105691057, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6991869918699187, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.7073170731707317, 0.4642857142857143, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.6991869918699187, 0.6071428571428571, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8760162601626016, 0.8214285714285714, 'Plas <= 157.5\ngini = 0.399\nsamples = 207\nvalue = [57, 150]'),
#  Text(0.790650406504065, 0.75, 'age <= 30.5\ngini = 0.476\nsamples = 115\nvalue = [45, 70]'),
#  Text(0.7479674796747967, 0.6785714285714286, 'Pres <= 61.0\ngini = 0.497\nsamples = 50\nvalue = [27, 23]'),
#  Text(0.7398373983739838, 0.6071428571428571, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(0.7560975609756098, 0.6071428571428571, 'mass <= 41.8\ngini = 0.439\nsamples = 40\nvalue = [27, 13]'),
#  Text(0.7398373983739838, 0.5357142857142857, 'pedi <= 1.141\ngini = 0.35\nsamples = 31\nvalue = [24, 7]'),
#  Text(0.7317073170731707, 0.4642857142857143, 'Preg <= 4.5\ngini = 0.285\nsamples = 29\nvalue = [24, 5]'),
#  Text(0.7154471544715447, 0.39285714285714285, 'Pres <= 73.0\ngini = 0.204\nsamples = 26\nvalue = [23, 3]'),
#  Text(0.7073170731707317, 0.32142857142857145, 'Preg <= 0.5\ngini = 0.42\nsamples = 10\nvalue = [7, 3]'),
#  Text(0.6910569105691057, 0.25, 'mass <= 33.75\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.6829268292682927, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.6991869918699187, 0.17857142857142858, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7235772357723578, 0.25, 'Pres <= 71.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(0.7154471544715447, 0.17857142857142858, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(0.7317073170731707, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.7235772357723578, 0.32142857142857145, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(0.7479674796747967, 0.39285714285714285, 'test <= 125.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.7398373983739838, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.7560975609756098, 0.32142857142857145, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7479674796747967, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7723577235772358, 0.5357142857142857, 'Plas <= 142.5\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.7642276422764228, 0.4642857142857143, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(0.7804878048780488, 0.4642857142857143, 'pedi <= 0.373\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.7723577235772358, 0.39285714285714285, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.7886178861788617, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8333333333333334, 0.6785714285714286, 'pedi <= 0.429\ngini = 0.4\nsamples = 65\nvalue = [18, 47]'),
#  Text(0.8130081300813008, 0.6071428571428571, 'mass <= 45.55\ngini = 0.497\nsamples = 28\nvalue = [13, 15]'),
#  Text(0.8048780487804879, 0.5357142857142857, 'pedi <= 0.136\ngini = 0.491\nsamples = 23\nvalue = [13, 10]'),
#  Text(0.7967479674796748, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8130081300813008, 0.4642857142857143, 'mass <= 32.45\ngini = 0.472\nsamples = 21\nvalue = [13, 8]'),
#  Text(0.8048780487804879, 0.39285714285714285, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.8211382113821138, 0.39285714285714285, 'mass <= 33.05\ngini = 0.5\nsamples = 16\nvalue = [8, 8]'),
#  Text(0.8130081300813008, 0.32142857142857145, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8292682926829268, 0.32142857142857145, 'skin <= 30.0\ngini = 0.473\nsamples = 13\nvalue = [8, 5]'),
#  Text(0.8130081300813008, 0.25, 'age <= 42.0\ngini = 0.346\nsamples = 9\nvalue = [7, 2]'),
#  Text(0.8048780487804879, 0.17857142857142858, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.8211382113821138, 0.17857142857142858, 'age <= 44.5\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(0.8130081300813008, 0.10714285714285714, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8292682926829268, 0.10714285714285714, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8455284552845529, 0.25, 'test <= 44.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.8373983739837398, 0.17857142857142858, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.8536585365853658, 0.17857142857142858, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.8211382113821138, 0.5357142857142857, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.8536585365853658, 0.6071428571428571, 'test <= 333.5\ngini = 0.234\nsamples = 37\nvalue = [5, 32]'),
#  Text(0.8373983739837398, 0.5357142857142857, 'mass <= 40.05\ngini = 0.161\nsamples = 34\nvalue = [3, 31]'),
#  Text(0.8292682926829268, 0.4642857142857143, 'gini = 0.0\nsamples = 24\nvalue = [0, 24]'),
#  Text(0.8455284552845529, 0.4642857142857143, 'Pres <= 80.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(0.8373983739837398, 0.39285714285714285, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(0.8536585365853658, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.8699186991869918, 0.5357142857142857, 'pedi <= 0.581\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8617886178861789, 0.4642857142857143, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8780487804878049, 0.4642857142857143, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.9613821138211383, 0.75, 'test <= 629.5\ngini = 0.227\nsamples = 92\nvalue = [12, 80]'),
#  Text(0.9390243902439024, 0.6785714285714286, 'pedi <= 0.3\ngini = 0.199\nsamples = 89\nvalue = [10, 79]'),
#  Text(0.9186991869918699, 0.6071428571428571, 'pedi <= 0.288\ngini = 0.365\nsamples = 25\nvalue = [6, 19]'),
#  Text(0.9105691056910569, 0.5357142857142857, 'age <= 37.5\ngini = 0.287\nsamples = 23\nvalue = [4, 19]'),
#  Text(0.8943089430894309, 0.4642857142857143, 'mass <= 45.6\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(0.8861788617886179, 0.39285714285714285, 'skin <= 28.0\ngini = 0.375\nsamples = 8\nvalue = [2, 6]'),
#  Text(0.8780487804878049, 0.32142857142857145, 'mass <= 32.8\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.8699186991869918, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.8861788617886179, 0.25, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8943089430894309, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.9024390243902439, 0.39285714285714285, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.926829268292683, 0.4642857142857143, 'age <= 56.5\ngini = 0.133\nsamples = 14\nvalue = [1, 13]'),
#  Text(0.9186991869918699, 0.39285714285714285, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]'),
#  Text(0.9349593495934959, 0.39285714285714285, 'skin <= 15.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.926829268292683, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.943089430894309, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.926829268292683, 0.5357142857142857, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.959349593495935, 0.6071428571428571, 'age <= 44.0\ngini = 0.117\nsamples = 64\nvalue = [4, 60]'),
#  Text(0.9512195121951219, 0.5357142857142857, 'gini = 0.0\nsamples = 47\nvalue = [0, 47]'),
#  Text(0.967479674796748, 0.5357142857142857, 'Preg <= 6.5\ngini = 0.36\nsamples = 17\nvalue = [4, 13]'),
#  Text(0.959349593495935, 0.4642857142857143, 'age <= 51.0\ngini = 0.494\nsamples = 9\nvalue = [4, 5]'),
#  Text(0.9512195121951219, 0.39285714285714285, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(0.967479674796748, 0.39285714285714285, 'mass <= 45.05\ngini = 0.278\nsamples = 6\nvalue = [1, 5]'),
#  Text(0.959349593495935, 0.32142857142857145, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.975609756097561, 0.32142857142857145, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.975609756097561, 0.4642857142857143, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(0.983739837398374, 0.6785714285714286, 'mass <= 33.4\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(0.975609756097561, 0.6071428571428571, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.991869918699187, 0.6071428571428571, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
tree_clf = DecisionTreeClassifier(max_depth=2, random_state=42)
tree_clf.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %%
plot_tree(tree_clf);

# %%
print(dtree.predict([[40, 10, 7, 1,3,3,2,5]])) #prediction of class
# Out:
# [1]
# C:\Users\Duha masoodi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
